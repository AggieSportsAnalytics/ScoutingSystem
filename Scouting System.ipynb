# %%
import pandas as pd #importing panda library
import math
import csv

# %%
playerStats = pd.read_csv('CollegeBasketballPlayers2009-2021.csv', low_memory = False) #reads CSV file into playerStats variable (low_memory = False becuase file is too big)

# %%
playerStats #print out playerStats csv file
# Out:
#               player_name              team  conf  GP  Min_per   Ortg   usg  \
# 0           DeAndrae Ross     South Alabama    SB  26     29.5   97.3  16.6
# 1           Pooh Williams          Utah St.   WAC  34     60.9  108.3  14.9
# 2           Jesus Verdejo     South Florida    BE  27     72.0   96.2  21.8
# 3         Mike Hornbuckle        Pepperdine   WCC  30     44.5   97.7  16.0
# 4           Anthony Brown           Pacific    BW  33     56.2   96.5  22.0
# ...                   ...               ...   ...  ..      ...    ...   ...
# 61056      Trey Patterson         Villanova    BE   2      0.3   60.5  19.3
# 61057  Stavros Polatoglou  Northwestern St.  Slnd   4      1.3   28.3   7.1
# 61058          Sandy Ryan            Tulane  Amer   1      0.1    0.0   0.0
# 61059           Ty Larson        Texas Tech   B12   1      0.1    0.0   0.0
# 61060         Jaden Jones           Rutgers   B10   4      1.0   89.6  28.8
#
# ...

# %%
df = pd.DataFrame(playerStats[['player_name', 'pick']])
for index, row in df.iterrows():
    if (math.isnan(row['pick']) == False): #change false and true for players drafted or not
        print(row['player_name'], row['pick'])
# Out:
# Charles Jenkins 44.0
# Ryan Reid 57.0
# Kyle Singler 33.0
# Nolan Smith 21.0
# E'Twaun Moore 55.0
# JaJuan Johnson 27.0
# Jordan Hill 8.0
# Chase Budinger 44.0
# Eric Maynor 20.0
# Jeremy Evans 55.0
# Earl Clark 14.0
# Dante Cunningham 33.0
# Greivis Vasquez 28.0
# Jermaine Taylor 32.0
# Goran Suton 50.0
# Derrick Brown 40.0
# Cole Aldrich 11.0
# Damion James 24.0
# Dexter Pittman 32.0
# Tyler Hansbrough 13.0
# Danny Green 46.0
# Lester Hudson 58.0
# Lavoy Allen 50.0
# Chinemelu Elonu 59.0
# Taj Gibson 26.0
# Stanley Robinson 59.0
# Jack McClinton 51.0
# Lazar Hayward 30.0
# DeJuan Blair 37.0
# Landry Fields 39.0
# DaJuan Summers 35.0
# Kenneth Faried 22.0
# Jeff Teague 19.0
# James Johnson 16.0
# Stephen Curry 7.0
# Solomon Alabi 50.0
# Jon Diebler 51.0
# Evan Turner 2.0
# Jon Leuer 40.0
# Gerald Henderson 12.0
# Robert Vaden 54.0
# Jonny Flynn 6.0
# Terrence Williams 11.0
# Dominique Jones 25.0
# Chandler Parsons 38.0
# Jon Brockman 38.0
# Darren Collison 21.0
# Ty Lawson 18.0
# ...
