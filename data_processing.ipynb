# %%
import pandas as pd
import numpy as np
import os
import math

# %%
#read dataset
df = pd.read_csv("CollegeBasketballPlayers2009-2021.csv")
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        player_name           team conf  GP  Min_per   Ortg   usg   eFG  \
# 0    DeAndrae Ross  South Alabama   SB  26     29.5   97.3  16.6  42.5
# 1    Pooh Williams       Utah St.  WAC  34     60.9  108.3  14.9  52.4
# 2    Jesus Verdejo  South Florida   BE  27     72.0   96.2  21.8  45.7
# 3  Mike Hornbuckle     Pepperdine  WCC  30     44.5   97.7  16.0  53.6
# 4    Anthony Brown        Pacific   BW  33     56.2   96.5  22.0  52.8
#
#    TS_per  ORB_per  ...     dgbpm    oreb    dreb    treb     ast     stl  \
# 0   44.43      1.6  ... -1.941150  0.1923  0.6154  0.8077  1.1923  0.3462
# 1   54.48      3.8  ... -0.247934  0.6765  1.2647  1.9412  1.8235  0.4118
# ...

# %%
min_minutes_played = 30

# %%
#remove all records where player played less than 5 minutes
df = pd.DataFrame(df[df['mp'] > min_minutes_played])
df.head()
# Out:
#         player_name           team conf  GP  Min_per   Ortg   usg   eFG  \
# 2     Jesus Verdejo  South Florida   BE  27     72.0   96.2  21.8  45.7
# 6        Dana Smith       Longwood  ind  27     77.8  104.8  23.0  53.4
# 8   Justin Drummond         Wagner  NEC  30     82.8   99.7  20.5  48.8
# 9       Jamal Smith         Wagner  NEC  30     80.4   92.5  23.0  43.5
# 13   Gary Wilkinson       Utah St.  WAC  34     79.9  124.8  24.0  57.9
#
#     TS_per  ORB_per  ...     dgbpm    oreb    dreb    treb     ast     stl  \
# 2    47.98      2.1  ... -0.883163  0.6296  2.3333  2.9630  1.9630  0.4815
# 6    56.30      6.8  ... -0.908391  2.1481  3.8889  6.0370  1.8148  1.7778
# 8    53.07      2.9  ...  0.919272  0.8000  3.9333  4.7333  4.1333  1.7333
# 9    45.29      6.4  ... -1.913070  1.7333  3.4667  5.2000  1.7333  1.2333
# 13   63.97      7.2  ... -0.233409  1.6765  4.9706  6.6471  1.2353  0.4706
#
#        blk      pts  Unnamed: 64  Unnamed: 65
# ...

# %%
print(df.columns)
print(df['Unnamed: 64'])
# Out:
# Index(['player_name', 'team', 'conf', 'GP', 'Min_per', 'Ortg', 'usg', 'eFG',
#        'TS_per', 'ORB_per', 'DRB_per', 'AST_per', 'TO_per', 'FTM', 'FTA',
#        'FT_per', 'twoPM', 'twoPA', 'twoP_per', 'TPM', 'TPA', 'TP_per',
#        'blk_per', 'stl_per', 'ftr', 'yr', 'ht', 'num', 'porpag', 'adjoe',
#        'pfr', 'year', 'pid', 'type', 'Rec Rank', 'ast/tov', 'rimmade',
#        'rimmade+rimmiss', 'midmade', 'midmade+midmiss',
#        'rimmade/(rimmade+rimmiss)', 'midmade/(midmade+midmiss)', 'dunksmade',
#        'dunksmiss+dunksmade', 'dunksmade/(dunksmade+dunksmiss)', 'pick',
#        'drtg', 'adrtg', 'dporpag', 'stops', 'bpm', 'obpm', 'dbpm', 'gbpm',
#        'mp', 'ogbpm', 'dgbpm', 'oreb', 'dreb', 'treb', 'ast', 'stl', 'blk',
#        'pts', 'Unnamed: 64', 'Unnamed: 65'],
#       dtype='object')
# 2            NaN
# 6            NaN
# 8            NaN
# 9            NaN
# 13           NaN
#           ...
# 60954    Combo G
# 60973    Combo G
# 60977     Wing G
# ...

# %%
positions = df['Unnamed: 64']

# %%
positions.unique()
# Out:
# array([nan, 'Wing F', 'Combo G', 'Scoring PG', 'Wing G', 'Pure PG',
#        'PF/C', 'Stretch 4', 'C'], dtype=object)

# %%
#rename position column

df = df.rename({'Unnamed: 64': 'position'}, axis=1)

# %%
df['position'].unique()
# Out:
# array([nan, 'Wing F', 'Combo G', 'Scoring PG', 'Wing G', 'Pure PG',
#        'PF/C', 'Stretch 4', 'C'], dtype=object)

# %%
#get all unique positions, remove null position
positions = []
for x in df['position'].unique():
    positions.append(x)
positions = positions[1:]
positions
# Out:
# ['Wing F',
#  'Combo G',
#  'Scoring PG',
#  'Wing G',
#  'Pure PG',
#  'PF/C',
#  'Stretch 4',
#  'C']

# %%
os.listdir('/Users/arnavakula/Code/repos/ScoutingSystem/split_by_position')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/zl/9t4bv8n91kz5kcy_mlv21l7m0000gn/T/ipykernel_66490/564376736.py in <module>
# ----> 1 os.listdir('/Users/arnavakula/Code/repos/ScoutingSystem/split_by_position')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/arnavakula/Code/repos/ScoutingSystem/split_by_position'

# %%
#create new dataset of all nba players for each position
all_players = pd.read_csv('split_by_position/wing-g.csv')
nba_players = pd.DataFrame()
for i in range(all_players.shape[0]):
    if not np.isnan(all_players.iloc[i].pick):
        nba_players = nba_players.append(all_players.iloc[i], ignore_index=True)

# %%
#write them to a .csv file
nba_players.to_csv('nba-wing-g.csv')
